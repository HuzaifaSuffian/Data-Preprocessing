# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('train.csv')

# %%
df = df[['Age','Fare','Survived']]

# %%
# Removing the missing values in age column
df.dropna(inplace=True)

# %%
# Train Test Split
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,:2],df.iloc[:,-1],test_size=0.2)

# %% [markdown]
# # Before Scaling the data

# %%
sns.kdeplot(X_train['Age'])
plt.title('Before Scaling Age')
# Out:
# Text(0.5, 1.0, 'Before Scaling Age')

# %%
sns.kdeplot(X_train['Fare'])
plt.title('Before Scaling Fare')
# Out:
# Text(0.5, 1.0, 'Before Scaling Fare')

# %%
plt.scatter(x=X_train['Age'],y=X_train['Fare'])

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
pred1 = lr.predict(X_test)
accuracy_score(y_test,pred1)
# Out:
# 0.6153846153846154

# %% [markdown]
# # Applying Standardization

# %%
sc = StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
sns.kdeplot(X_train_scaled['Age'])
plt.title('After Scaling Age')
# Out:
# Text(0.5, 1.0, 'After Scaling Age')

# %%
sns.kdeplot(X_train_scaled['Fare'])
plt.title('After Scaling Fare')
# Out:
# Text(0.5, 1.0, 'After Scaling Fare')

# %%
plt.scatter(x=X_train_scaled['Age'], y=X_train_scaled['Fare'])

# %%
lr = LogisticRegression()
lr.fit(X_train_scaled,y_train)
pred1 = lr.predict(X_test_scaled)
accuracy_score(y_test,pred1)
# Out:
# 0.6083916083916084

# %% [markdown]
# ### Standardization helps scaler the values between 0 to 1. It helps in improving the result but may be this dataset is not appropriate that much.
